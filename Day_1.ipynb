# %% [markdown]
# <a href="https://colab.research.google.com/github/kritikamandale/Python_is_a_language/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello guys welcome to my channel")
# Out:
# hello guys welcome to my channel

# %%
m1 = int(input("enter marks 1 - "))
m2 = int(input("enter marks 2 - "))
m3 = int(input("enter marks 3 - "))
m4 = int(input("enter marks 4 - "))
m52 = int(input("enter marks 5 - "))
per = (m1+m2+m3+m4+m5)/5
print(round(per))
# Out:
# enter marks 1 - 12
# enter marks 2 - 2
# enter marks 3 - 11
# enter marks 4 - 1
# enter marks 5 - 2
# 25

# %%
if(per<=100 and per>=75):
    print("Grade A")
elif(per<=75 and per>=60):
    print("Grade B")
elif(per<=60 and per>=45):
    print("Grade C")
else :
    print("Fail")
# Out:
# Fail

# %%
kri = "kritika"
kri
# Out:
# 'kritika'

# %%
kri[2]
# Out:
# 'i'

# %%
for i in kri:
    print (i)
# Out:
# k
# r
# i
# t
# i
# k
# a

# %%
sentance = input(" ur input - ")
# Out:
# 3

# %%
xyz = "kritika"

# %%
xyz[0:4]
# Out:
# 'krit'

# %%
xyz[-1]
# Out:
# 'a'

# %%
for i in xyz:
  print(i)
# Out:
# k
# r
# i
# t
# i
# k
# a

# %%
print(xyz.index("t"))
# Out:
# 3

# %%
sentence = input()
# Out:
# my name is kritika and i am fine

# %%
#words = sentence.split()

# %%
print(words[: : -1])
# Out:
# ['fine', 'am', 'i', 'and', 'kritika', 'is', 'name', 'my']

# %%
half = len(sentence)//2
middle_word = sentence.index("a")
print(middle_word)
# Out:
# 4
